# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasa890/python/blob/main/Matploitlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 60])
ypoints = np.array([0, 400])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 20, 40, 60])
ypoints = np.array([0, 25, 35, 45])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["M", "A", "N", "A", "S", "A"])
y = np.array([4, 9, 1, 10, 7, 6,])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["clad", "vdc", "physics", "maths1", "maths2", "IT Productive tools", "English", "Programming with C", "Visualisation"])
y = np.array([91.22, 80, 86, 68, 78, 68, 88.5, 93.6, 99])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([91.22, 80, 86, 68, 78, 68, 88.5, 93.6, 99])
a = (["clad", "vdc", "phy", "maths1", "maths2", "IT Prod", "Eng", "Program", "Visul"])

plt.pie(y,labels=a)
plt.show()
